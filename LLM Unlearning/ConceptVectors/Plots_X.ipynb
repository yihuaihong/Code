# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
methods = ['Needle', 'Needle', 'Needle', 'Needle', 'NPO_KL', 'NPO_KL', 'NPO_KL', 'NPO', 'NPO', 'NPO', 'DPO', 'DPO', 'DPO', 'Grad Diff', 'Grad Diff', 'Grad Diff', 'MEMIT Empty', 'MEMIT Entropy']

unlearn_bleu_scores = [0.03023292002148334, 0.05687013871701468,0.11240242675496616, 0.3012974255413713 ,0.4638657695432425,0.2758323728558635,0.1065500949769718,   0.4966755373266607, 0.3596638084194765,0.0774286012, 0.2094025195690416, 0.4244723861,0.5432367210926875 ,0.53835203160942, 0.1749624036315595,0.00063787095, 0.1558699262163939, 0.23011544191746203]
unrelated_bleu_scores = [0.7057149818215002, 0.8315330246836659,0.8860677427792151,0.9275367292866556,0.5302704120586043,0.23747721353139453,0.12380018263608014,0.5748184559932283, 0.29561508933994846,0.07007998644806829,
   0.24903990445371252 , 0.5797677988631623, 0.7995279904434079, 0.703828522287083, 0.25165961162264977,0.0012325554965626404, 0.5291970158709141, 0.5778632509062812]

# 图形大小和子图
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# 定义标记和颜色
colors_markers = {
    "Needle": ('purple', '*'),
    "NPO_KL": ('c', 'p'),
    "NPO": ('b', 'v'),
    "DPO": ('orange', 'o'),
    "Grad Diff": ('r', '^'),
    "MEMIT Empty": ('green', 'x'),
    "MEMIT Entropy": ('cyan', 'h'),
    "NPO_KL(MLP)": ('black', 'd'),
    "Grad Ascent": ('grey','s')
}

# 第一个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax1.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax1.set_xlim(-0.02, 1.02)
ax1.set_ylim(-0.02, 1.025)

ax1.set_xlabel('Target QA BLEU', fontsize=20)
ax1.set_ylabel('Unrelated QA BLEU', fontsize=20)

ax1.text(0.023, 0.969, 'GOAL', fontsize=15, fontweight='bold')


methods = ['Needle', 'Needle', 'Needle', 'Needle', 'NPO_KL', 'NPO_KL','NPO_KL', 'NPO', 'NPO', 'NPO', 'DPO', 'DPO', 'DPO',  'Grad Diff','Grad Diff', 'Grad Diff', 'MEMIT Entropy', 'MEMIT Empty']

unlearn_bleu_scores = [0.3547183446514928,0.20253726485725,0.1765728585113025,0.1208883958785375, 0.3356047161815894, 0.23555798442881937,0.1576989300310124, 0.1748913703120794, 0.2635320894570494,  0.3356047161815894, 0.21480476991334826, 0.2974347415584704, 0.12588513841094706, 0.29803566554338334, 0.3504664407783983, 0.34992600553842884, 0.19996396884938022, 0.050189720482484046]
unrelated_bleu_scores = [0.8039259435061569,0.623456598550054,0.4867104196387267,0.35632373355567293, 0.657922309823519 ,0.32282593666899106, 0.09762833060582696, 0.18841835698703202, 0.3432095481509418, 0.6479684535249058, 0.27983105357309845, 0.4809935246057835, 0.20791531823062326, 0.45258922125295137, 0.7226202996028939,0.7216613189069132, 0.6548620466744085, 0.5572920692828375]


# 第二个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax2.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax2.set_xlim(-0.02, 1.02)
ax2.set_ylim(-0.02, 1.025)
ax2.set_xlabel('Target QA BLEU', fontsize=20)
#ax2.set_ylabel('Unrelated-QA Bleu', fontsize=15)

ax2.text(0.023, 0.967, 'GOAL', fontsize=15, fontweight='bold')
xticks = np.arange(0, 1.01, 0.25)
ax1.set_xticks(xticks)
ax2.set_xticks(xticks)

ax1.tick_params(axis='both', which='major', labelsize=19)
ax2.tick_params(axis='both', which='major', labelsize=19)


ax1.set_title('LLaMA with jailbreak', fontsize=19)
ax2.set_title('OLMo with jailbreak', fontsize=19)




# 创建一个包含两个子图的图例
handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', fontsize=19, ncol=4, bbox_to_anchor=(0.5, 1.13), handletextpad=0.03)
ax2.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)
ax1.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)

# 调整布局
plt.tight_layout()
plt.subplots_adjust(top=0.85)

# 显示和保存图形
plt.savefig('QA_Bleu_jailbreak.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
methods = ['Needle', 'Needle', 'Needle', 'Needle', 'NPO_KL', 'NPO_KL', 'NPO_KL', 'NPO', 'NPO', 'NPO', 'DPO', 'DPO', 'DPO', 'Grad Diff', 'Grad Diff', 'Grad Diff', 'MEMIT Empty', 'MEMIT Entropy']

unlearn_rouge_scores = [0.502619238673905, 0.2942563133382994, 0.20565647988355107, 0.11648485490693809, 0.2886772878228925 , 0.4784161191630398, 0.645082859283551, 0.2496677121195925, 0.5613776971801015,  0.66478221697215, 0.4155607515246133, 0.6054911328155564, 0.6975275057020787, 0.6903406169442468, 0.33428308489761, 0.0145729518706164, 0.33617082027315187, 0.4299464556201512, 0.33617082027315187,0.4299464556201512]
unrelated_rouge_scores = [0.9531852508810046, 0.9287414641004491, 0.8927365257856985, 0.8083556975727213, 0.36664196, 0.467437044922758, 0.6879773610516781, 0.2846750582407338, 0.5195301820899467,  0.7209534326747646 ,0.4570251253157571,  0.71144868794921, 0.8703238523044161,0.7975617499137982, 0.46185873987052845, 0.030048848462222586,0.6568334291769342 , 0.7097502390861674, 0.6568334291769342, 0.7097502390861674]



# 图形大小和子图
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# 定义标记和颜色
colors_markers = {
    "Needle": ('purple', '*'),
    "NPO_KL": ('c', 'p'),
    "NPO": ('b', 'v'),
    "DPO": ('orange', 'o'),
    "Grad Diff": ('r', '^'),
    "MEMIT Empty": ('green', 'x'),
    "MEMIT Entropy": ('cyan', 'h'),
    "NPO_KL(MLP)": ('black', 'd'),
    "Grad Ascent": ('grey','s')
}

# 第一个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_rouge_scores[j] for j in indices]
    xs = [unlearn_rouge_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax1.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax1.set_xlim(-0.02, 1.02)
ax1.set_ylim(-0.02, 1.025)

ax1.set_xlabel('Target QA ROUGE-L', fontsize=20)
ax1.set_ylabel('Unrelated QA ROUGE-L', fontsize=20)

ax1.text(0.023, 0.969, 'GOAL', fontsize=15, fontweight='bold')


methods = ['Needle', 'Needle', 'Needle', 'Needle', 'NPO_KL', 'NPO_KL','NPO_KL', 'NPO', 'NPO', 'NPO', 'DPO', 'DPO', 'DPO',  'Grad Diff','Grad Diff', 'Grad Diff', 'MEMIT Empty','MEMIT Entropy']

Needle_unrelated = [0.8618468809938324,0.7230942141488761,0.6309974177179442,0.5245070276237475]
Needle_score = [0.5056320091352806, 0.345830842195795, 0.3105676529175725, 0.2313331521345908]

npo_KL_unrelated = [0.21762833060582696, 0.5032322914522406,0.757922309823519]
npo_KL_score = [0.2776989300310124, 0.373229860928122, 0.4556047161815894]

npo_unrelated = [0.36030008148255643, 0.5006390174037851, 0.7879684535]
npo_score = [0.2898021093425281, 0.3817946171393608, 0.4456047161815894]

Grad_Diff_unrelated = [0.55258922125295137, 0.7826202996028939,0.8016613189069132]
Grad_Diff_score = [0.37803566554338334, 0.4304664407783983, 0.45992600553842884]


# 0.80735385392885
# 0.3504664407783983

dpo_unrelated = [0.4631038339774985, 0.49705415046055107, 0.8341719441467843]
dpo_score = [0.3328231218021618, 0.3531969409762918, 0.48449082775441]

memit_entropy_score = [0.17498651560726454]
memit_entropy_unrelated = [0.6741408724905111]

memit_dummy_score = [0.11998651560726454]
memit_dummy_unrelated = [0.6041408724905111]

unrelated_rouge_scores = Needle_unrelated + npo_KL_unrelated + npo_unrelated + dpo_unrelated + Grad_Diff_unrelated + memit_dummy_unrelated + memit_entropy_unrelated
unlearn_rouge_scores = Needle_score + npo_KL_score + npo_score + dpo_score + Grad_Diff_score +  memit_dummy_score  + memit_entropy_score


# 第二个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_rouge_scores[j] for j in indices]
    xs = [unlearn_rouge_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax2.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax2.set_xlim(-0.02, 1.02)
ax2.set_ylim(-0.02, 1.025)
ax2.set_xlabel('Target QA ROUGE-L', fontsize=20)
#ax2.set_ylabel('Unrelated-QA Bleu', fontsize=15)

ax2.text(0.023, 0.967, 'GOAL', fontsize=15, fontweight='bold')
xticks = np.arange(0, 1.01, 0.25)
ax1.set_xticks(xticks)
ax2.set_xticks(xticks)

ax1.tick_params(axis='both', which='major', labelsize=19)
ax2.tick_params(axis='both', which='major', labelsize=19)


ax1.set_title('LLaMA with jailbreak', fontsize=19)
ax2.set_title('OLMo with jailbreak', fontsize=19)




# 创建一个包含两个子图的图例
handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', fontsize=19, ncol=4, bbox_to_anchor=(0.5, 1.13), handletextpad=0.03)
ax2.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)
ax1.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)

# 调整布局
plt.tight_layout()
plt.subplots_adjust(top=0.85)

# 显示和保存图形
plt.savefig('QA_Rouge_jailbreak.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
methods = ['Needle', 'Needle', 'Needle', 'Needle', 'NPO_KL', 'NPO_KL', 'NPO_KL', 'NPO', 'NPO', 'NPO', 'DPO', 'DPO', 'DPO', 'Grad Diff', 'Grad Diff', 'Grad Diff', 'MEMIT Empty', 'MEMIT Entropy']
unlearn_rouge_scores = [0.502619238673905, 0.2942563133382994, 0.20565647988355107, 0.11648485490693809, 0.2886772878228925 , 0.4784161191630398, 0.645082859283551, 0.2496677121195925, 0.5613776971801015,  0.66478221697215, 0.4155607515246133, 0.6054911328155564, 0.6975275057020787, 0.6903406169442468, 0.33428308489761, 0.0145729518706164, 0.33617082027315187, 0.4299464556201512]
unrelated_rouge_scores = [0.9531852508810046, 0.9287414641004491, 0.8927365257856985, 0.8083556975727213, 0.36664196, 0.467437044922758, 0.6879773610516781, 0.2846750582407338, 0.5195301820899467,  0.7209534326747646 ,0.4570251253157571,  0.71144868794921, 0.8703238523044161,0.7975617499137982, 0.46185873987052845, 0.030048848462222586,0.6568334291769342 , 0.7097502390861674]
colors = ['r', 'c',   'b',  'purple' ,'orange']
markers = [ '^', 'p',  'v',  '*', 'o']
markersizes = [12] * 16


memit_entropy_rouge_scores = [0.4299464556201512]
memit_entropy_unrelated_rouge_scores = [0.7097502390861674]
memit_dummy_rouge_scores = [0.33617082027315187]
memit_dummy_unrelated_rouge_scores = [0.6568334291769342]


# 设置图形大小
plt.figure(figsize=(5, 4.0))

# 绘制数据点和连接线
for i, method in enumerate(set(methods)):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_rouge_scores[j] for j in indices]
    xs = [unlearn_rouge_scores[j] for j in indices]
    print(method)
    if method == "Needle":
      color1 = 'purple'
      marker = '*'
    if method == "NPO_KL":
      color1 = 'c'
      marker = 'p'
    if method == "NPO":
      color1 = 'b'
      marker = 'v'
    if method == "DPO":
      color1 = 'orange'
      marker = 'o'
    if str(method) == "Grad Diff":
      color1 = 'r'
      marker = '^'
    if str(method) == "MEMIT Empty":
      color1 = 'green'
      marker = 'x'
    if str(method) == "MEMIT Entropy":
      color1 = 'cyan'
      marker = 'h'

    plt.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method,  markersize=markersizes[i])

# 添加目标点


# 设置坐标轴范围和标签
plt.xlim(-0.02, 1.02)  # 设置x轴范围略微大于1.0
plt.ylim(-0.02, 1.025)  # 设置y轴范围略微大于1.0
# plt.gca().set_xlim(0, 1)  # 设置实际显示的x轴范围为0到1
# plt.gca().set_ylim(0, 1)  # 设置实际显示的y轴范围为0到1
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.xlabel('QA Rouge-L',fontsize=15)
plt.ylabel('Unrelated-QA Rouge-L',fontsize=15)

# 添加图例
plt.legend()
plt.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)
plt.text(0.023, 0.969, 'GOAL', fontsize=14, fontweight='bold') #bbox=dict(facecolor='white', alpha=0.5)
#plt.title('Jailbreak Unlearning Performance(Rouge-L) on LLaMA2')
# 显示图形
#plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9)
plt.savefig('QA_Rouge_jailbreak.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# NPO_KL
# NPO
# MEMIT Entropy
# Needle
# DPO
# Grad Diff
# MEMIT Empty

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
methods_jailbreak = ['Needle(Jailbreak)', 'Needle(Jailbreak)', 'Needle(Jailbreak)', 'Needle(Jailbreak)','MEMIT Empty(Jailbreak)', 'MEMIT Empty(Jailbreak)' , 'MEMIT Empty(Jailbreak)','MEMIT Entropy(Jailbreak)','MEMIT Entropy(Jailbreak)','MEMIT Entropy(Jailbreak)', 'DPO(Jailbreak)','DPO(Jailbreak)','DPO(Jailbreak)']
methods = ['Needle(Normal)', 'Needle(Normal)', 'Needle(Normal)', 'Needle(Normal)','MEMIT Empty(Normal)', 'MEMIT Empty(Normal)' , 'MEMIT Empty(Normal)','MEMIT Entropy(Normal)','MEMIT Entropy(Normal)','MEMIT Entropy(Normal)','DPO(Normal)','DPO(Normal)','DPO(Normal)']

Needle_unlearn_bleu_scores_jailbreak = [0.03023292002148334, 0.05687013871701468,0.11240242675496616, 0.3012974255413713]
Needle_jaccard_scores_jailbreak = [0.051470616048255695, 0.11287351781629025, 0.27684791520125257, 0.378]
MEMIT_Empty_bleu_scores_jailbreak = [0.1558699262163939,0.2788699262163939,0.32258699262163939]
MEMIT_Empty_jaccard_scores_jailbreak = [0.633,0.722,0.826]
MEMIT_Entropy_bleu_scores_jailbreak = [0.1251544191746203,0.20011544191746203,0.23011544191746203]
MEMIT_Entropy_jaccard_scores_jailbreak = [0.621,0.743,0.810]

DPO_bleu_scores_jailbreak = [0.162,0.259,0.437]
DPO_jaccard_scores_jailbreak = [0.948,0.983,0.993]

unlearn_bleu_scores_jailbreak = Needle_unlearn_bleu_scores_jailbreak + MEMIT_Empty_bleu_scores_jailbreak + MEMIT_Entropy_bleu_scores_jailbreak + DPO_bleu_scores_jailbreak
jaccard_scores_jailbreak = Needle_jaccard_scores_jailbreak + MEMIT_Empty_jaccard_scores_jailbreak + MEMIT_Entropy_jaccard_scores_jailbreak + DPO_jaccard_scores_jailbreak


methods = methods_jailbreak + methods

Needle_unlearn_bleu_scores = [0.0087183446514928,0.02553726485725,0.0465728585113025,0.1308883958785375]
Needle_jaccard_scores = [0.051470616048255695, 0.11287351781629025, 0.27684791520125257, 0.378]
MEMIT_Empty_bleu_scores = [0.048396396884938022,0.14296396884938022,0.2296396884938022]
MEMIT_Empty_jaccard_scores = [0.633,0.722,0.826]
MEMIT_Entropy_bleu_scores= [0.08189720482484046,0.1210189720482484046,0.1810189720482484046]
MEMIT_Entropy_jaccard_scores = [0.621,0.743,0.810]

DPO_bleu_scores = [0.123,0.179,0.356]
DPO_jaccard_scores = [0.948,0.983,0.993]



unlearn_bleu_scores = Needle_unlearn_bleu_scores + MEMIT_Empty_bleu_scores + MEMIT_Entropy_bleu_scores + DPO_bleu_scores
jaccard_scores = Needle_jaccard_scores + MEMIT_Empty_jaccard_scores + MEMIT_Entropy_jaccard_scores + DPO_jaccard_scores

unlearn_bleu_scores = unlearn_bleu_scores_jailbreak + unlearn_bleu_scores
jaccard_scores = jaccard_scores_jailbreak + jaccard_scores

# 图形大小和子图
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# 定义标记和颜色
colors_markers = {
    "Needle(Normal)": ('purple', 'v'),
    "NPO_KL": ('c', 'p'),
    "NPO": ('b', 'v'),
    "DPO(Normal)": ('orange', 'D'),
    "DPO(Jailbreak)": ('orange', 'o'),
    "Grad Diff": ('r', '^'),
    "MEMIT Empty(Normal)": ('green', 's'),
    "MEMIT Entropy(Normal)": ('cyan', '^'),
    "NPO_KL(MLP)": ('black', 'd'),
    "Grad Ascent": ('grey','s'),
    "Needle(Jailbreak)": ('purple', '*'),
    "MEMIT Empty(Jailbreak)": ('green', 'x'),
    "MEMIT Entropy(Jailbreak)": ('cyan', 'h'),
}

# 第一个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unlearn_bleu_scores[j] for j in indices]
    xs = [jaccard_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax1.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=8)

ax1.set_xlim(-0.02, 1.02)
ax1.set_ylim(-0.02, 1.025)

ax1.set_xlabel('Target Vector Jaccard Similarity', fontsize=20)
ax1.set_ylabel('Target QA BLEU', fontsize=20)

# ax1.text(0.023, 0.969, 'GOAL', fontsize=15, fontweight='bold')

methods_jailbreak = ['Needle(Jailbreak)', 'Needle(Jailbreak)', 'Needle(Jailbreak)', 'Needle(Jailbreak)','MEMIT Empty(Jailbreak)', 'MEMIT Empty(Jailbreak)' , 'MEMIT Empty(Jailbreak)','MEMIT Entropy(Jailbreak)','MEMIT Entropy(Jailbreak)','MEMIT Entropy(Jailbreak)', 'DPO(Jailbreak)','DPO(Jailbreak)','DPO(Jailbreak)']
methods = ['Needle(Normal)', 'Needle(Normal)', 'Needle(Normal)', 'Needle(Normal)','MEMIT Empty(Normal)', 'MEMIT Empty(Normal)' , 'MEMIT Empty(Normal)','MEMIT Entropy(Normal)','MEMIT Entropy(Normal)','MEMIT Entropy(Normal)','DPO(Normal)','DPO(Normal)','DPO(Normal)']

Needle_unlearn_bleu_scores_jailbreak = [0.3747183446514928,0.22253726485725,0.1865728585113025,0.0948883958785375]
Needle_jaccard_scores_jailbreak = [0.324402263839668282,0.25002263839668282,0.102263839668282,0.00402263839668282]
MEMIT_Empty_bleu_scores_jailbreak = [0.10396396884938022,0.19996396884938022,0.2596396884938022]
MEMIT_Empty_jaccard_scores_jailbreak = [0.514,0.634,0.774]
MEMIT_Entropy_bleu_scores_jailbreak = [0.050189720482484046,0.1110189720482484046,0.2310189720482484046]
MEMIT_Entropy_jaccard_scores_jailbreak = [0.4760,0.590,0.7820]

DPO_bleu_scores_jailbreak = [0.162,0.278,0.437]
DPO_jaccard_scores_jailbreak = [0.945,0.971,0.988]

unlearn_bleu_scores_jailbreak = Needle_unlearn_bleu_scores_jailbreak + MEMIT_Empty_bleu_scores_jailbreak + MEMIT_Entropy_bleu_scores_jailbreak + DPO_bleu_scores_jailbreak
jaccard_scores_jailbreak = Needle_jaccard_scores_jailbreak + MEMIT_Empty_jaccard_scores_jailbreak + MEMIT_Entropy_jaccard_scores_jailbreak + DPO_jaccard_scores_jailbreak



methods = methods_jailbreak + methods

Needle_unlearn_bleu_scores = [0.2601183446514928,0.1313726485725,0.096545728585113025,0.0431883958785375]
Needle_jaccard_scores = [0.324402263839668282,0.25002263839668282,0.102263839668282,0.00402263839668282]
MEMIT_Empty_bleu_scores = [0.0496396884938022,0.10596396884938022,0.1536396884938022]
MEMIT_Empty_jaccard_scores = [0.514,0.634,0.774]
MEMIT_Entropy_bleu_scores= [0.042189720482484046,0.06510189720482484046,0.1410189720482484046]
MEMIT_Entropy_jaccard_scores = [0.4760,0.590,0.7820]

DPO_bleu_scores = [0.113,0.159,0.340]
DPO_jaccard_scores = [0.945,0.971,0.988]

unlearn_bleu_scores = Needle_unlearn_bleu_scores + MEMIT_Empty_bleu_scores + MEMIT_Entropy_bleu_scores + DPO_bleu_scores
jaccard_scores = Needle_jaccard_scores + MEMIT_Empty_jaccard_scores + MEMIT_Entropy_jaccard_scores + DPO_jaccard_scores

unlearn_bleu_scores = unlearn_bleu_scores_jailbreak + unlearn_bleu_scores
jaccard_scores = jaccard_scores_jailbreak + jaccard_scores

# 第二个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unlearn_bleu_scores[j] for j in indices]
    xs = [jaccard_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax2.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=8)

ax2.set_xlim(-0.02, 1.02)
ax2.set_ylim(-0.02, 1.025)
ax2.set_xlabel('Target Vector Jaccard Similarity', fontsize=20)
#ax2.set_ylabel('Unrelated-QA Bleu', fontsize=15)

# ax2.text(0.023, 0.967, 'GOAL', fontsize=15, fontweight='bold')
xticks = np.arange(0, 1.01, 0.25)
ax1.set_xticks(xticks)
ax2.set_xticks(xticks)

ax1.tick_params(axis='both', which='major', labelsize=19)
ax2.tick_params(axis='both', which='major', labelsize=19)


ax1.set_title('Llama2-7B-chat', fontsize=19)
ax2.set_title('OLMo-7B', fontsize=19)




# 创建一个包含两个子图的图例
handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', fontsize=19, ncol=4, bbox_to_anchor=(0.5, 1.13), handletextpad=0.03)
# ax2.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)
# ax1.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)

# 调整布局
plt.tight_layout()
plt.subplots_adjust(top=0.85)

# 显示和保存图形
plt.savefig('QA_Bleu_Intrinsic.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 Needle_unlearn_bleu_scores_jailbreak  - Needle_unlearn_bleu_scores
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据

methods = ['Needle', 'Needle', 'Needle', 'Needle','MEMIT Empty', 'MEMIT Empty' , 'MEMIT Empty','MEMIT Entropy','MEMIT Entropy','MEMIT Entropy']

Needle_unlearn_bleu_scores_jailbreak = [0.03023292002148334, 0.05687013871701468,0.11240242675496616, 0.3012974255413713]
Needle_jaccard_scores_jailbreak = [0.051470616048255695, 0.11287351781629025, 0.27684791520125257, 0.378]
MEMIT_Empty_bleu_scores_jailbreak = [0.1558699262163939,0.2788699262163939,0.32258699262163939]
MEMIT_Empty_jaccard_scores_jailbreak = [0.633,0.722,0.826]
MEMIT_Entropy_bleu_scores_jailbreak = [0.1251544191746203,0.20011544191746203,0.23011544191746203]
MEMIT_Entropy_jaccard_scores_jailbreak = [0.621,0.743,0.810]

DPO_bleu_scores_jailbreak = [0.162,0.259,0.437]
DPO_jaccard_scores_jailbreak = [0.948,0.983,0.993]

unlearn_bleu_scores_jailbreak = Needle_unlearn_bleu_scores_jailbreak + MEMIT_Empty_bleu_scores_jailbreak + MEMIT_Entropy_bleu_scores_jailbreak #+ DPO_bleu_scores_jailbreak
jaccard_scores_jailbreak = Needle_jaccard_scores_jailbreak + MEMIT_Empty_jaccard_scores_jailbreak + MEMIT_Entropy_jaccard_scores_jailbreak #+ DPO_jaccard_scores_jailbreak


Needle_unlearn_bleu_scores = [0.0087183446514928,0.02553726485725,0.0465728585113025,0.1308883958785375]
Needle_jaccard_scores = [0.051470616048255695, 0.11287351781629025, 0.27684791520125257, 0.378]
MEMIT_Empty_bleu_scores = [0.048396396884938022,0.14296396884938022,0.2296396884938022]
MEMIT_Empty_jaccard_scores = [0.633,0.722,0.826]
MEMIT_Entropy_bleu_scores= [0.08189720482484046,0.1210189720482484046,0.1810189720482484046]
MEMIT_Entropy_jaccard_scores = [0.621,0.743,0.810]

DPO_bleu_scores = [0.123,0.179,0.356]
DPO_jaccard_scores = [0.948,0.983,0.993]



unlearn_bleu_scores = Needle_unlearn_bleu_scores + MEMIT_Empty_bleu_scores + MEMIT_Entropy_bleu_scores #+ DPO_bleu_scores
jaccard_scores = Needle_jaccard_scores + MEMIT_Empty_jaccard_scores + MEMIT_Entropy_jaccard_scores #+ DPO_jaccard_scores

differences_unlearn_bleu_scores = [a - b for a, b in zip(unlearn_bleu_scores_jailbreak, unlearn_bleu_scores)]

# 图形大小和子图
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# 定义标记和颜色
colors_markers = {
    "NPO_KL": ('c', 'p'),
    "NPO": ('b', 'v'),
    "DPO": ('orange', 'o'),
    "Grad Diff": ('r', '^'),
    "NPO_KL(MLP)": ('black', 'd'),
    "Grad Ascent": ('grey','s'),
    "Needle": ('purple', '*'),
    "MEMIT Empty": ('green', 'x'),
    "MEMIT Entropy": ('cyan', 'h'),
}

# 第一个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [differences_unlearn_bleu_scores[j] for j in indices]
    xs = [jaccard_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    errors = {'Needle':[0.00922586, 0.01422586, 0.01822586,0.02522586],'MEMIT Empty':[0.02522586, 0.02522586,0.03922586],'MEMIT Entropy':[0.02622586, 0.02122586, 0.04422586], 'DPO': [0.010422586, 0.027622586, 0.040922586]}
    print(len(ys))
    # ax1.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=8)
    ax1.errorbar(xs, ys, yerr=errors[method], linestyle='--', marker=marker, color=color1, label=method, markersize=12, capsize=5)

ax1.set_xlim(-0.02, 1.02)
ax1.set_ylim(-0.02, 0.35)

ax1.set_xlabel('Target Vector Jaccard Similarity', fontsize=20)
ax1.set_ylabel('Differences in Target QA BLEU', fontsize=20)

# ax1.text(0.023, 0.969, 'GOAL', fontsize=15, fontweight='bold')

methods = ['Needle', 'Needle', 'Needle', 'Needle','MEMIT Empty', 'MEMIT Empty' , 'MEMIT Empty','MEMIT Entropy','MEMIT Entropy','MEMIT Entropy']

Needle_unlearn_bleu_scores_jailbreak = [0.3747183446514928,0.22253726485725,0.1865728585113025,0.0948883958785375]
Needle_jaccard_scores_jailbreak = [0.324402263839668282,0.25002263839668282,0.102263839668282,0.00402263839668282]
MEMIT_Empty_bleu_scores_jailbreak = [0.10396396884938022,0.19996396884938022,0.2596396884938022]
MEMIT_Empty_jaccard_scores_jailbreak = [0.514,0.634,0.774]
MEMIT_Entropy_bleu_scores_jailbreak = [0.050189720482484046,0.1110189720482484046,0.2310189720482484046]
MEMIT_Entropy_jaccard_scores_jailbreak = [0.4760,0.590,0.7820]

DPO_bleu_scores_jailbreak = [0.162,0.278,0.437]
DPO_jaccard_scores_jailbreak = [0.945,0.971,0.988]

unlearn_bleu_scores_jailbreak = Needle_unlearn_bleu_scores_jailbreak + MEMIT_Empty_bleu_scores_jailbreak + MEMIT_Entropy_bleu_scores_jailbreak #+ DPO_bleu_scores_jailbreak
jaccard_scores_jailbreak = Needle_jaccard_scores_jailbreak + MEMIT_Empty_jaccard_scores_jailbreak + MEMIT_Entropy_jaccard_scores_jailbreak #+ DPO_jaccard_scores_jailbreak


Needle_unlearn_bleu_scores = [0.2401183446514928,0.1313726485725,0.096545728585113025,0.0431883958785375]
Needle_jaccard_scores = [0.324402263839668282,0.25002263839668282,0.102263839668282,0.00402263839668282]
MEMIT_Empty_bleu_scores = [0.0496396884938022,0.10596396884938022,0.1536396884938022]
MEMIT_Empty_jaccard_scores = [0.514,0.634,0.774]
MEMIT_Entropy_bleu_scores= [0.042189720482484046,0.06510189720482484046,0.1410189720482484046]
MEMIT_Entropy_jaccard_scores = [0.4760,0.590,0.7820]

DPO_bleu_scores = [0.113,0.159,0.340]
DPO_jaccard_scores = [0.945,0.971,0.988]

unlearn_bleu_scores = Needle_unlearn_bleu_scores + MEMIT_Empty_bleu_scores + MEMIT_Entropy_bleu_scores #+ DPO_bleu_scores
jaccard_scores = Needle_jaccard_scores + MEMIT_Empty_jaccard_scores + MEMIT_Entropy_jaccard_scores #+ DPO_jaccard_scores

differences_unlearn_bleu_scores = [a - b for a, b in zip(unlearn_bleu_scores_jailbreak, unlearn_bleu_scores)]

# 第二个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [differences_unlearn_bleu_scores[j] for j in indices]
    xs = [jaccard_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    # ax2.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=12)
    errors = {'Needle':[0.03622586, 0.02622586, 0.02022586,0.01122586],'MEMIT Empty':[0.03122586, 0.02822586,0.04422586],'MEMIT Entropy':[0.03822586, 0.02622586, 0.04422586], 'DPO': [0.021422586, 0.031622586, 0.041922586]}
    print(len(ys))
    # ax1.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=8)
    ax2.errorbar(xs, ys, yerr=errors[method], linestyle='--', marker=marker, color=color1, label=method, markersize=12, capsize=5)

ax2.set_xlim(-0.02, 1.02)
ax2.set_ylim(-0.02, 0.35)
ax2.set_xlabel('Target Vector Jaccard Similarity', fontsize=20)
#ax2.set_ylabel('Unrelated-QA Bleu', fontsize=15)

# ax2.text(0.023, 0.967, 'GOAL', fontsize=15, fontweight='bold')
xticks = np.arange(0, 1.01, 0.25)
ax1.set_xticks(xticks)
ax2.set_xticks(xticks)

ax1.tick_params(axis='both', which='major', labelsize=19)
ax2.tick_params(axis='both', which='major', labelsize=19)


ax1.set_title('Llama2-7B-chat', fontsize=19)
ax2.set_title('OLMo-7B', fontsize=19)




# 创建一个包含两个子图的图例
handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', fontsize=19, ncol=4, bbox_to_anchor=(0.5, 1.13), handletextpad=0.03)
# ax2.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)
# ax1.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)

# 调整布局
plt.tight_layout()
plt.subplots_adjust(top=0.85)

# 显示和保存图形
plt.savefig('QA_Bleu_Intrinsic.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# 3
# 3
# 4
# 3
# 3
# 4

# %%
data = [0.201,0.236,0.249,0.302,0.340,0.162]
np.var(data, ddof=1)
# Out:
# 0.004225866666666666

# %%
#plots for Rouge score
import matplotlib.pyplot as plt
import numpy as np

# 数据
methods = ['Needle', 'Needle', 'Needle', 'Needle', 'NPO_KL', 'NPO_KL', 'NPO_KL', 'NPO', 'NPO', 'NPO', 'DPO', 'DPO', 'DPO', 'Grad Diff', 'Grad Diff', 'Grad Diff', 'MEMIT Empty', 'MEMIT Entropy']

unlearn_bleu_scores = [0.03023292002148334, 0.05687013871701468,0.11240242675496616, 0.3012974255413713 ,0.4638657695432425,0.2758323728558635,0.1065500949769718,   0.4966755373266607, 0.3596638084194765,0.0774286012, 0.2094025195690416, 0.4244723861,0.5432367210926875 ,0.53835203160942, 0.1749624036315595,0.00063787095, 0.1558699262163939, 0.23011544191746203]
unrelated_bleu_scores = [0.7057149818215002, 0.8315330246836659,0.8860677427792151,0.9275367292866556,0.5302704120586043,0.23747721353139453,0.12380018263608014,0.5748184559932283, 0.29561508933994846,0.07007998644806829,
   0.24903990445371252 , 0.5797677988631623, 0.7995279904434079, 0.703828522287083, 0.25165961162264977,0.0012325554965626404, 0.5291970158709141, 0.5778632509062812]

# 图形大小和子图
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# 定义标记和颜色
colors_markers = {
    "Needle": ('purple', '*'),
    "NPO_KL": ('c', 'p'),
    "NPO": ('b', 'v'),
    "DPO": ('orange', 'o'),
    "Grad Diff": ('r', '^'),
    "MEMIT Empty": ('green', 'x'),
    "MEMIT Entropy": ('cyan', 'h'),
    "NPO_KL(MLP)": ('black', 'd'),
    "Grad Ascent": ('grey','s')
}

# 第一个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax1.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax1.set_xlim(-0.02, 1.02)
ax1.set_ylim(-0.02, 1.025)

ax1.set_xlabel('Target QA GOUGE-L', fontsize=20)
ax1.set_ylabel('Unrelated QA GOUGE-L', fontsize=20)

ax1.text(0.023, 0.969, 'GOAL', fontsize=15, fontweight='bold')


methods = ['Needle', 'Needle', 'Needle', 'Needle', 'NPO_KL', 'NPO_KL','NPO_KL', 'NPO', 'NPO', 'NPO', 'DPO', 'DPO', 'DPO',  'Grad Diff','Grad Diff', 'Grad Diff', 'MEMIT Entropy', 'MEMIT Empty']

unlearn_bleu_scores = [0.3547183446514928,0.20253726485725,0.1765728585113025,0.1208883958785375, 0.3356047161815894, 0.23555798442881937,0.1576989300310124, 0.1748913703120794, 0.2635320894570494,  0.3356047161815894, 0.21480476991334826, 0.2974347415584704, 0.12588513841094706, 0.29803566554338334, 0.3504664407783983, 0.34992600553842884, 0.19996396884938022, 0.050189720482484046]
unrelated_bleu_scores = [0.8039259435061569,0.623456598550054,0.4867104196387267,0.35632373355567293, 0.657922309823519 ,0.32282593666899106, 0.09762833060582696, 0.18841835698703202, 0.3432095481509418, 0.6479684535249058, 0.27983105357309845, 0.4809935246057835, 0.20791531823062326, 0.45258922125295137, 0.7226202996028939,0.7216613189069132, 0.6548620466744085, 0.5572920692828375]


# 第二个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax2.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax2.set_xlim(-0.02, 1.02)
ax2.set_ylim(-0.02, 1.025)
ax2.set_xlabel('Target QA GOUGE-L', fontsize=20)
#ax2.set_ylabel('Unrelated-QA Bleu', fontsize=15)

ax2.text(0.023, 0.967, 'GOAL', fontsize=15, fontweight='bold')
xticks = np.arange(0, 1.01, 0.25)
ax1.set_xticks(xticks)
ax2.set_xticks(xticks)

ax1.tick_params(axis='both', which='major', labelsize=19)
ax2.tick_params(axis='both', which='major', labelsize=19)


ax1.set_title('LLaMA with jailbreak', fontsize=19)
ax2.set_title('OLMo with jailbreak', fontsize=19)




# 创建一个包含两个子图的图例
handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', fontsize=19, ncol=4, bbox_to_anchor=(0.5, 1.13), handletextpad=0.03)
ax2.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)
ax1.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)

# 调整布局
plt.tight_layout()
plt.subplots_adjust(top=0.85)

# 显示和保存图形
plt.savefig('QA_Rouge_jailbreak.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# 数据
methods = ['Needle', 'Needle', 'Needle', 'Needle', 'NPO_KL', 'NPO_KL', 'NPO_KL', 'NPO', 'NPO', 'NPO', 'DPO', 'DPO', 'DPO', 'Grad Diff', 'Grad Diff', 'Grad Diff', 'MEMIT Empty', 'MEMIT Entropy']


# 图形大小和子图
fig, (ax3, ax4) = plt.subplots(1, 2, figsize=(10, 5))

# 定义标记和颜色
colors_markers = {
    "Needle": ('purple', '*'),
    "NPO_KL": ('c', 'p'),
    "NPO": ('b', 'v'),
    "DPO": ('orange', 'o'),
    "Grad Diff": ('r', '^'),
    "MEMIT Empty": ('green', 'x'),
    "MEMIT Entropy": ('cyan', 'h'),
    "NPO_KL(MLP)": ('black', 'd'),
    "Grad Ascent": ('grey','s')
}
methods = [ 'Grad Diff', 'Grad Ascent','Needle', 'NPO_KL',  'NPO',  'DPO', 'MEMIT Empty', 'MEMIT Entropy', 'NPO_KL(MLP)']
unlearn_bleu_scores = [0.131,0.119,0.462 ,0.195, 0.186, 0.179, 0.0871 ,0.0355, 0.245]
unrelated_bleu_scores = [0.235, 0.169, 0.534, 0.298, 0.262,0.263, 0.379, 0.349, 0.303]
colors = ['r', 'c',   'b',  'purple' ,'orange', 'green','grey']
markers = [ '^', 'p',  'v',  '*', 'o',  'x','t']

# 第三个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax3.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax3.set_xlim(-0.02, 1.02)
ax3.set_ylim(-0.02, 1.025)
ax3.set_xlabel('Target QA BLEU', fontsize=20)
ax3.set_ylabel('Unrelated QA BLEU', fontsize=20)
#ax3.set_ylabel('Unrelated-QA Bleu', fontsize=15)

ax3.text(0.023, 0.967, 'GOAL', fontsize=15, fontweight='bold')




methods = [ 'Grad Diff', 'Grad Ascent','Needle', 'NPO_KL',  'NPO',  'DPO', 'MEMIT Empty','MEMIT Entropy', 'NPO_KL(MLP)']
unlearn_bleu_scores = [0.148 ,0.056,0.313 ,0.191, 0.065 , 0.159  , 0.121 ,0.053, 0.205 ]
unrelated_bleu_scores = [0.059 , 0.057, 0.447 , 0.173 , 0.159,0.066 , 0.316, 0.319, 0.279 ]
colors = ['r', 'c',   'b',  'purple' ,'orange', 'green','grey']
markers = [ '^', 'p',  'v',  '*', 'o',  'x','t']

# 第四个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax4.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax4.set_xlim(-0.02, 1.02)
ax4.set_ylim(-0.02, 1.025)
ax4.set_xlabel('Target QA BLEU', fontsize=20)
#ax4.set_ylabel('Unrelated-QA Bleu', fontsize=15)
ax4.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)
ax4.text(0.023, 0.967, 'GOAL', fontsize=15, fontweight='bold')

xticks = np.arange(0, 1.01, 0.25)
ax3.set_xticks(xticks)
ax4.set_xticks(xticks)

ax3.tick_params(axis='both', which='major', labelsize=19)
ax4.tick_params(axis='both', which='major', labelsize=19)

ax3.set_title('LLaMA without jailbreak', fontsize=19)
ax4.set_title('OLMo without jailbreak', fontsize=19)



# 创建一个包含两个子图的图例
handles, labels = ax3.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', fontsize=19, ncol=4, bbox_to_anchor=(0.5, 1.2), handletextpad=0.03)
ax3.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)

# 调整布局
plt.tight_layout()
plt.subplots_adjust(top=0.85)

# 显示和保存图形
plt.savefig('QA_Bleu_main_results.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# **Needle Abaltion Experiment**

# %%
import matplotlib.pyplot as plt
import numpy as np

# 图形大小和子图
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))


# 数据
methods = ['Noise', 'Noise', 'Noise', 'Needle+Grad Ascent','Needle+Grad Ascent', 'Needle+Grad Ascent',
      "Needle+Grad Diff","Needle+Grad Diff","Needle+Grad Diff","Needle+DPO","Needle+DPO","Needle+DPO",
      "Needle+NPO","Needle+NPO","Needle+NPO","Needle+NPO_KL","Needle+NPO_KL","Needle+NPO_KL"]

noise_unlearn_bleu = [0.5470752113245757, 0.29676731346860774, 0.20068665097953411]
noise_unlearn_unrelated_bleu = [0.7847714107507114, 0.7359820947858804, 0.6878651611882574]

unlearn_bleu_scores = np.random.rand(len(methods))
unrelated_bleu_scores = np.random.rand(len(methods))


# 定义标记和颜色
colors_markers = {
    "Noise": ('purple', '*'),
    "Needle+Grad Ascent": ('c', 'p'),
    "Needle+Grad Diff": ('b', 'v'),
    "Needle+DPO": ('orange', 'o'),
    "Needle+NPO": ('r', '^'),
    "Needle+NPO_KL": ('black', 'd'),
}

# 第一个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax1.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax1.set_xlim(-0.02, 1.02)
ax1.set_ylim(-0.02, 1.025)

ax1.set_xlabel('Target QA BLEU', fontsize=20)
ax1.set_ylabel('Unrelated QA BLEU', fontsize=20)
ax1.text(0.023, 0.969, 'GOAL', fontsize=15, fontweight='bold')


methods = ['Noise', 'Noise', 'Noise', 'Needle+Grad Ascent','Needle+Grad Ascent', 'Needle+Grad Ascent',
      "Needle+Grad Diff","Needle+Grad Diff","Needle+Grad Diff","Needle+DPO","Needle+DPO","Needle+DPO",
      "Needle+NPO","Needle+NPO","Needle+NPO","Needle+NPO_KL","Needle+NPO_KL","Needle+NPO_KL"]

noise_unlearn_bleu = [0.3405932117557215, 0.29973807361791466, 0.2608895524605017]
noise_unlearn_unrelated_bleu = [0.4038810960925481, 0.34073964204218926, 0.3115729260392651]




# 定义标记和颜色
colors_markers = {
    "Noise": ('purple', '*'),
    "Needle+Grad Ascent": ('c', 'p'),
    "Needle+Grad Diff": ('b', 'v'),
    "Needle+DPO": ('orange', 'o'),
    "Needle+NPO": ('r', '^'),
    "Needle+NPO_KL": ('black', 'd'),
}

# 第一个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax2.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax2.set_xlim(-0.02, 1.02)
ax2.set_ylim(-0.02, 1.025)

ax2.set_xlabel('Target QA BLEU', fontsize=20)
ax2.set_ylabel('Unrelated QA BLEU', fontsize=20)

ax2.text(0.023, 0.969, 'GOAL', fontsize=15, fontweight='bold')


methods = ['Noise', 'Noise', 'Noise', 'Needle+Grad Ascent','Needle+Grad Ascent', 'Needle+Grad Ascent',
      "Needle+Grad Diff","Needle+Grad Diff","Needle+Grad Diff","Needle+DPO","Needle+DPO","Needle+DPO",
      "Needle+NPO","Needle+NPO","Needle+NPO","Needle+NPO_KL","Needle+NPO_KL","Needle+NPO_KL"]

unlearn_bleu_scores = np.random.rand(len(methods))
unrelated_bleu_scores = np.random.rand(len(methods))


# 定义标记和颜色
colors_markers = {
    "Noise": ('purple', '*'),
    "Needle+Grad Ascent": ('grey', 't'),
    "Needle+Grad Diff": ('b', 'v'),
    "Needle+DPO": ('orange', 'o'),
    "Needle+NPO": ('r', '^'),
    "Needle+NPO_KL": ('black', 'd'),
}


for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax3.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax3.set_xlim(-0.02, 1.02)
ax3.set_ylim(-0.02, 1.025)

ax3.set_xlabel('Target QA BLEU', fontsize=20)
ax3.set_ylabel('Unrelated QA BLEU', fontsize=20)

ax3.text(0.023, 0.969, 'GOAL', fontsize=15, fontweight='bold')


methods = ['Noise', 'Noise', 'Noise', 'Needle+Grad Ascent','Needle+Grad Ascent', 'Needle+Grad Ascent',
      "Needle+Grad Diff","Needle+Grad Diff","Needle+Grad Diff","Needle+DPO","Needle+DPO","Needle+DPO",
      "Needle+NPO","Needle+NPO","Needle+NPO","Needle+NPO_KL","Needle+NPO_KL","Needle+NPO_KL"]

unlearn_bleu_scores = np.random.rand(len(methods))
unrelated_bleu_scores = np.random.rand(len(methods))

# 第二个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax4.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax4.set_xlim(-0.02, 1.02)
ax4.set_ylim(-0.02, 1.025)
ax4.set_xlabel('Target QA BLEU', fontsize=20)
#ax2.set_ylabel('Unrelated-QA Bleu', fontsize=15)

ax4.text(0.023, 0.967, 'GOAL', fontsize=15, fontweight='bold')
xticks = np.arange(0, 1.01, 0.25)
ax1.set_xticks(xticks)
ax2.set_xticks(xticks)
ax3.set_xticks(xticks)
ax4.set_xticks(xticks)

ax1.tick_params(axis='both', which='major', labelsize=19)
ax2.tick_params(axis='both', which='major', labelsize=19)
ax3.tick_params(axis='both', which='major', labelsize=19)
ax4.tick_params(axis='both', which='major', labelsize=19)

ax1.set_title('Needle Abalation on LLaMA', fontsize=19)
ax2.set_title('Needle Abalation on OLMo', fontsize=19)
ax3.set_title('Needle+Other loss fc on LLaMA', fontsize=19)
ax4.set_title('Needle+Other loss fc on OLMo', fontsize=19)


# 创建一个包含两个子图的图例
handles, labels = ax4.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', fontsize=19, ncol=4, bbox_to_anchor=(0.5, 1.13), handletextpad=0.03)

ax1.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)
ax2.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)
ax3.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)
ax4.scatter(0.0053, 0.994, marker='*', color='gold', label='GOAL', s=200)

# 调整布局
plt.tight_layout()
plt.subplots_adjust(top=0.85)

# 显示和保存图形
plt.savefig('Needle Abalation Experiment.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 图形大小和子图
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))


# 数据
methods = ['Noise', 'Noise', 'Noise', 'Needle+Grad Ascent(no Noise)','Needle+Grad Ascent(no Noise)', 'Needle+Grad Ascent(no Noise)',"Needle+NPO_KL(no Noise)","Needle+NPO_KL(no Noise)","Needle+NPO_KL(no Noise)",'Needle+Grad Ascent', 'Needle+Grad Ascent', 'Needle+Grad Ascent',"Needle+NPO_KL","Needle+NPO_KL","Needle+NPO_KL" ]

noise_unlearn_bleu = [0.5470752113245757, 0.29676731346860774, 0.20068665097953411]
noise_unlearn_unrelated_bleu = [0.7847714107507114, 0.7359820947858804, 0.6878651611882574]

ga_score = [0.030696368356360287, 0.24876151885855843,0.7716057970106641]
ga_unrelated_score = [0.48716158124623854, 0.7137653064074209, 0.827847926092008]
gd_score = [0.7840178696402522, 0.2659511239709943, 0.025408317887955542]
gd_unrelated_score = [0.8420821040120803,0.740054341924972, 0.5110348743365681]
dpo_score = [0.045746822853798136, 0.27562447939685664, 0.779208505926599]
dpo_unrelated_score = [0.5176297044193421, 0.7366224422520817, 0.8227795527969802]
npo_score = [0.05491305333431273, 0.2832546584170598, 0.7533420505568112]
npo_unrelated_score = [0.523472750161792, 0.733173079036638, 0.8230245532979803]
npo_KL_score = [0.05480357047564517, 0.2834103817910686, 0.7533420505568112]
npo_KL_unrelated_score = [0.5235724055531384, 0.7245997716972808,0.8230245532979803]

ga_score_noise = [0.027522502251995352, 0.17382796777400283, 0.5420502370771181]
ga_unrelated_score_noise = [0.48658209804332225, 0.7257457367820084, 0.7996346827982501]
gd_score_noise = [0.02133763053820016, 0.2109016384802348,0.5523965643885022]
gd_unrelated_score_noise = [0.5199227379986282, 0.7257859460974452,0.8018827830849775]
npo_KL_score_noise = [0.05343151445196646, 0.23828155901867887, 0.5460024907537783]
npo_KL_unrelated_score_noise = [0.5299632501420513, 0.7348833696443925, 0.8097714024566514]

unrelated_bleu_scores = noise_unlearn_unrelated_bleu + ga_unrelated_score  + npo_KL_unrelated_score + ga_unrelated_score_noise + npo_KL_unrelated_score_noise
unlearn_bleu_scores = noise_unlearn_bleu + ga_score + npo_KL_score +  ga_score_noise + npo_KL_score_noise

# 定义标记和颜色
colors_markers = {
    "Noise": ('purple', '*'),
    "Needle+Grad Ascent(no Noise)": ('c', '>'),
    "Needle+Grad Diff(no Noise)": ('r', 'P'),
    "Needle+NPO_KL(no Noise)": ('k', 'X'),
    "Noise": ('purple', '*'),
    "Needle+Grad Ascent": ('c', 'p'),
    "Needle+Grad Diff": ('r', '^'),
    "Needle+DPO": ('orange', 'o'),
    "Needle+NPO": ('b', 'v'),
    "Needle+NPO_KL": ('black', 'd'),
}

#     "New Method 2": ('grey', '8'),
#     "New Method 3": ('lime', 'H'),
#     "New Method 4": ('navy', 'D'),
#     "New Method 5": ('gold', 'X'),
#     "New Method 6": ('teal', 'P')


# 第一个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax1.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax1.set_xlim(-0.02, 0.90)
ax1.set_ylim(0.45, 0.85) #1.025

ax1.set_xticks(np.arange(0, 0.90, 0.2))
ax1.set_yticks(np.arange(0.4, 0.90, 0.1))

ax1.set_xlabel('Target QA BLEU', fontsize=20)
ax1.set_ylabel('Unrelated QA BLEU', fontsize=20)
# ax1.text(0.023, 0.985, 'GOAL', fontsize=15, fontweight='bold')


methods = ['Noise', 'Noise', 'Noise', 'Needle+Grad Ascent','Needle+Grad Ascent', 'Needle+Grad Ascent',
      "Needle+Grad Diff","Needle+Grad Diff","Needle+Grad Diff","Needle+DPO","Needle+DPO","Needle+DPO",
      "Needle+NPO","Needle+NPO","Needle+NPO","Needle+NPO_KL","Needle+NPO_KL","Needle+NPO_KL"]

noise_unlearn_bleu = [0.5470752113245757, 0.29676731346860774, 0.20068665097953411]
noise_unlearn_unrelated_bleu = [0.7847714107507114, 0.7359820947858804, 0.6878651611882574]

ga_score = [0.027522502251995352, 0.17382796777400283, 0.5420502370771181]
ga_unrelated_score = [0.48658209804332225, 0.7257457367820084, 0.7996346827982501]
gd_score = [0.02133763053820016, 0.2109016384802348,0.5523965643885022]
gd_unrelated_score = [0.5199227379986282, 0.7257859460974452,0.8018827830849775]
dpo_score = [0.5648044863347682, 0.2547040461225704, 0.054236231806277]
dpo_unrelated_score = [0.79625930395655,  0.7415611785613075, 0.5296835945828495]
npo_score = [0.5461415055126707, 0.041270291389161634, 0.027522502251995352]
npo_unrelated_score = [0.7938606147603625, 0.524322781581779, 0.48658209804332225]
npo_KL_score = [0.05343151445196646, 0.23828155901867887, 0.5460024907537783]
npo_KL_unrelated_score = [0.5299632501420513, 0.7348833696443925, 0.8097714024566514]

unrelated_bleu_scores = noise_unlearn_unrelated_bleu + ga_unrelated_score + gd_unrelated_score + dpo_unrelated_score + npo_unrelated_score + npo_KL_unrelated_score
unlearn_bleu_scores = noise_unlearn_bleu + ga_score + gd_score + dpo_score + npo_score + npo_KL_score

# noise_unlearn_bleu = [0.3405932117557215, 0.29973807361791466, 0.2608895524605017]
# noise_unlearn_unrelated_bleu = [0.4038810960925481, 0.34073964204218926, 0.3115729260392651]





for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax2.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=16)

ax2.set_xlim(-0.02, 0.65)
ax2.set_ylim(0.45, 0.85) #1.025

ax2.set_xticks(np.arange(0, 0.65, 0.1))
ax2.set_yticks(np.arange(0.4, 0.90, 0.1))

ax2.set_xlabel('Target QA BLEU', fontsize=20)
# ax2.set_ylabel('Unrelated QA BLEU', fontsize=20)

# ax2.text(0.023, 0.985, 'GOAL', fontsize=15, fontweight='bold')
ax1.tick_params(axis='both', which='major', labelsize=19)
ax2.tick_params(axis='both', which='major', labelsize=19)

ax1.set_title('Ablation Experiment on LLaMA', fontsize=19)
ax2.set_title('Needle+Loss Functions on LLaMA', fontsize=19)


handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()

# 合并图例句柄和标签，去重
handles = handles1 + handles2
labels = labels1 + labels2
unique_labels = dict(zip(labels, handles))

# 创建一个包含两个子图的合并图例
fig.legend(unique_labels.values(), unique_labels.keys(), loc='upper center', fontsize=19, ncol=4, bbox_to_anchor=(0.5, 1.13), handletextpad=0.03)


# ax1.scatter(0.0053, 0.997, marker='*', color='gold', label='GOAL', s=200)
# ax2.scatter(0.0053, 0.997, marker='*', color='gold', label='GOAL', s=200)

# 调整布局
plt.tight_layout()
plt.subplots_adjust(top=0.85)

# 显示和保存图形
plt.savefig('Needle Ablation Experiment.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 图形大小和子图
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# 数据
methods = ['Noise', 'Noise', 'Noise', 'Needle+Grad Ascent(no Noise)','Needle+Grad Ascent(no Noise)', 'Needle+Grad Ascent(no Noise)',
      "Needle+Grad Diff(no Noise)","Needle+Grad Diff(no Noise)","Needle+Grad Diff(no Noise)","Needle+DPO(no Noise)","Needle+DPO(no Noise)","Needle+DPO(no Noise)",
      "Needle+NPO(no Noise)","Needle+NPO(no Noise)","Needle+NPO(no Noise)","Needle+NPO_KL(no Noise)","Needle+NPO_KL(no Noise)","Needle+NPO_KL(no Noise)"]

noise_unlearn_bleu = [0.5470752113245757, 0.29676731346860774, 0.20068665097953411]
noise_unlearn_unrelated_bleu = [0.7847714107507114, 0.7359820947858804, 0.6878651611882574]

ga_score = [0.030696368356360287, 0.24876151885855843,0.7716057970106641]
ga_unrelated_score = [0.48716158124623854, 0.7337653064074209, 0.827847926092008]
gd_score = [0.7840178696402522, 0.2659511239709943, 0.025408317887955542]
gd_unrelated_score = [0.8420821040120803,0.740054341924972, 0.5110348743365681]
dpo_score = [0.045746822853798136, 0.27562447939685664, 0.779208505926599]
dpo_unrelated_score = [0.5176297044193421, 0.7366224422520817, 0.8227795527969802]
npo_score = [0.05491305333431273, 0.2832546584170598, 0.7533420505568112]
npo_unrelated_score = [0.523472750161792, 0.733173079036638, 0.8230245532979803]
npo_KL_score = [0.05480357047564517, 0.2834103817910686, 0.7533420505568112]
npo_KL_unrelated_score = [0.5235724055531384, 0.7445997716972808,0.8230245532979803]

unrelated_bleu_scores = noise_unlearn_unrelated_bleu + ga_unrelated_score + gd_unrelated_score + dpo_unrelated_score + npo_unrelated_score + npo_KL_unrelated_score
unlearn_bleu_scores = noise_unlearn_bleu + ga_score + gd_score + dpo_score + npo_score + npo_KL_score

# 定义标记和颜色
colors_markers = {
    "Noise": ('g', '*'),
    "Needle+Grad Ascent(no Noise)": ('b', 's'),
    "Needle+Grad Diff(no Noise)": ('r', '^'),
    "Needle+DPO(no Noise)": ('m', 'o'),
    "Needle+NPO(no Noise)": ('c', 'v'),
    "Needle+NPO_KL(no Noise)": ('k', 'd'),
}

# 第一个子图
for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax1.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=12)

ax1.set_xlim(-0.02, 0.90)
ax1.set_ylim(0.45, 1.025)

ax1.set_xlabel('Target QA BLEU', fontsize=15)
ax1.set_ylabel('Unrelated QA BLEU', fontsize=15)
ax1.text(0.023, 0.985, 'GOAL', fontsize=12, fontweight='bold')


methods = ['Noise', 'Noise', 'Noise', 'Needle+Grad Ascent','Needle+Grad Ascent', 'Needle+Grad Ascent',
      "Needle+Grad Diff","Needle+Grad Diff","Needle+Grad Diff","Needle+DPO","Needle+DPO","Needle+DPO",
      "Needle+NPO","Needle+NPO","Needle+NPO","Needle+NPO_KL","Needle+NPO_KL","Needle+NPO_KL"]

noise_unlearn_bleu = [0.5470752113245757, 0.29676731346860774, 0.20068665097953411]
noise_unlearn_unrelated_bleu = [0.7847714107507114, 0.7359820947858804, 0.6878651611882574]

ga_score = [0.027522502251995352, 0.17382796777400283, 0.5420502370771181]
ga_unrelated_score = [0.48658209804332225, 0.7257457367820084, 0.7996346827982501]
gd_score = [0.02133763053820016, 0.2109016384802348,0.5523965643885022]
gd_unrelated_score = [0.5199227379986282, 0.7257859460974452,0.8018827830849775]
dpo_score = [0.5648044863347682, 0.2547040461225704, 0.054236231806277]
dpo_unrelated_score = [0.79625930395655,  0.7415611785613075, 0.5296835945828495]
npo_score = [0.5461415055126707, 0.041270291389161634, 0.027522502251995352]
npo_unrelated_score = [0.7938606147603625, 0.524322781581779, 0.48658209804332225]
npo_KL_score = [0.05343151445196646, 0.23828155901867887, 0.5460024907537783]
npo_KL_unrelated_score = [0.5299632501420513, 0.7348833696443925, 0.8097714024566514]

unrelated_bleu_scores = noise_unlearn_unrelated_bleu + ga_unrelated_score + gd_unrelated_score + dpo_unrelated_score + npo_unrelated_score + npo_KL_unrelated_score
unlearn_bleu_scores = noise_unlearn_bleu + ga_score + gd_score + dpo_score + npo_score + npo_KL_score

# 定义标记和颜色
colors_markers = {
    "Noise": ('purple', '*'),
    "Needle+Grad Ascent": ('c', 'p'),
    "Needle+Grad Diff": ('r', '^'),
    "Needle+DPO": ('orange', 'o'),
    "Needle+NPO": ('b', 'v'),
    "Needle+NPO_KL": ('black', 'd'),
}

for method in set(methods):
    indices = [j for j, m in enumerate(methods) if m == method]
    ys = [unrelated_bleu_scores[j] for j in indices]
    xs = [unlearn_bleu_scores[j] for j in indices]
    color1, marker = colors_markers[method]
    ax2.plot(xs, ys, linestyle='--', marker=marker, color=color1, label=method, markersize=12)

ax2.set_xlim(-0.02, 0.65)
ax2.set_ylim(0.45, 1.025)

ax2.set_xlabel('Target QA BLEU', fontsize=15)
ax2.set_ylabel('Unrelated QA BLEU', fontsize=15)

ax2.text(0.023, 0.985, 'GOAL', fontsize=12, fontweight='bold')

# 获取两个子图的图例句柄和标签
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()

# 合并图例句柄和标签，去重
handles = handles1 + handles2
labels = labels1 + labels2
unique_labels = dict(zip(labels, handles))

# 创建一个包含两个子图的合并图例
fig.legend(unique_labels.values(), unique_labels.keys(), loc='upper center', fontsize=13, ncol=3, bbox_to_anchor=(0.5, 1.1), handletextpad=0.03)

ax1.scatter(0.0053, 0.997, marker='*', color='gold', label='GOAL', s=150)
ax2.scatter(0.0053, 0.997, marker='*', color='gold', label='GOAL', s=150)

# 调整布局
plt.tight_layout()
plt.subplots_adjust(top=0.85)

# 显示和保存图形
plt.savefig('Needle_Abalation_Experiment.pdf', format='pdf', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
import requests

API_TOKEN = "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"
headers = {"Authorization": f"Bearer {API_TOKEN}"}
API_URL = "https://huggingface.co/api/datasets/yihuaihong/conceptvectors/croissant"

def query():
    response = requests.get(API_URL, headers=headers)
    return response.json()

data = query()
data
# Out:
# {'@context': {'@language': 'en',
#   '@vocab': 'https://schema.org/',
#   'citeAs': 'cr:citeAs',
#   'column': 'cr:column',
#   'conformsTo': 'dct:conformsTo',
#   'cr': 'http://mlcommons.org/croissant/',
#   'data': {'@id': 'cr:data', '@type': '@json'},
#   'dataBiases': 'cr:dataBiases',
#   'dataCollection': 'cr:dataCollection',
#   'dataType': {'@id': 'cr:dataType', '@type': '@vocab'},
#   'dct': 'http://purl.org/dc/terms/',
#   'extract': 'cr:extract',
#   'field': 'cr:field',
#   'fileProperty': 'cr:fileProperty',
#   'fileObject': 'cr:fileObject',
#   'fileSet': 'cr:fileSet',
#   'format': 'cr:format',
#   'includes': 'cr:includes',
#   'isLiveDataset': 'cr:isLiveDataset',
#   'jsonPath': 'cr:jsonPath',
#   'key': 'cr:key',
#   'md5': 'cr:md5',
#   'parentField': 'cr:parentField',
#   'path': 'cr:path',
#   'personalSensitiveInformation': 'cr:personalSensitiveInformation',
#   'recordSet': 'cr:recordSet',
#   'references': 'cr:references',
#   'regex': 'cr:regex',
# ...
